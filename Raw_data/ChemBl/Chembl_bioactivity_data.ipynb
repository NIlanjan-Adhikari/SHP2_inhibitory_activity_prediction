# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for shp2**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('shp2')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references      organism  \
# 0  [{'xref_id': 'P35235', 'xref_name': None, 'xre...  Mus musculus
# 1  [{'xref_id': 'Q06124', 'xref_name': None, 'xre...  Homo sapiens
# 2                                                 []  Homo sapiens
#
#                              pref_name  score  species_group_flag  \
# 0      Protein-tyrosine phosphatase 2C   17.0               False
# 1      Protein-tyrosine phosphatase 2C   15.0               False
# 2  VHL/Protein-tyrosine phosphatase 2C   13.0               False
#
#   target_chembl_id                                  target_components  \
# 0       CHEMBL2620  [{'accession': 'P35235', 'component_descriptio...
# 1       CHEMBL3864  [{'accession': 'Q06124', 'component_descriptio...
# 2    CHEMBL4630742  [{'accession': 'Q06124', 'component_descriptio...
#
#                    target_type  tax_id
# 0               SINGLE PROTEIN   10090
# 1               SINGLE PROTEIN    9606
# 2  PROTEIN-PROTEIN INTERACTION    9606

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL3864'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *coronavirus 3C-like proteinase* (CHEMBL3927) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#      activity_comment  activity_id  \
# 0                None       185463
# 1                None       213040
# 2                None       558682
# 3                None       576834
# 4                None       596575
# ...               ...          ...
# 1234             None     22982901
# 1235             None     22982902
# 1236             None     22982903
# 1237   Not Determined     22982904
# 1238             None     22982905
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL764641
# 1                                                    []    CHEMBL764641
# 2                                                    []    CHEMBL805163
# 3                                                    []    CHEMBL805163
# 4                                                    []    CHEMBL812686
# ...                                                 ...             ...
# 1234  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4773301
# 1235  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4773301
# 1236  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4773301
# 1237  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4773301
# 1238  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4773301
#
#                                       assay_description assay_type  \
# 0     Inhibition of Syp(N) SH2 domain block binding ...          B
# 1     Inhibition of Syp(N) SH2 domain block binding ...          B
# 2     Inhibitory activity against SH2 domain of SH-P...          F
# 3     Inhibitory activity against SH2 domain of SH-P...          F
# 4     In vitro inhibitory concentration required aga...          B
# ...                                                 ...        ...
# 1234  Inhibition of recombinant SHP2 (unknown origin...          B
# 1235  Inhibition of recombinant SHP2 (unknown origin...          B
# 1236  Inhibition of recombinant SHP2 (unknown origin...          B
# 1237  Inhibition of recombinant SHP2 (unknown origin...          B
# 1238  Inhibition of recombinant SHP2 (unknown origin...          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000357
# 1                       None                   None  BAO_0000190  BAO_0000357
# 2                       None                   None  BAO_0000190  BAO_0000019
# 3                       None                   None  BAO_0000190  BAO_0000019
# 4                       None                   None  BAO_0000190  BAO_0000357
# ...                      ...                    ...          ...          ...
# 1234                    None                   None  BAO_0000179  BAO_0000357
# 1235                    None                   None  BAO_0000179  BAO_0000357
# 1236                    None                   None  BAO_0000179  BAO_0000357
# 1237                    None                   None  BAO_0000179  BAO_0000357
# 1238                    None                   None  BAO_0000179  BAO_0000357
#
#       ... target_organism                 target_pref_name target_tax_id  \
# 0     ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# 1     ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# 2     ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# 3     ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# 4     ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# ...   ...             ...                              ...           ...
# 1234  ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# 1235  ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# 1236  ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# 1237  ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# 1238  ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
#
#      text_value  toid  type  units    uo_units upper_value  value
# 0          None  None  IC50     uM  UO_0000065        None  100.0
# 1          None  None  IC50     uM  UO_0000065        None  100.0
# 2          None  None  IC50     uM  UO_0000065        None   1.54
# 3          None  None  IC50     uM  UO_0000065        None   22.0
# 4          None  None  IC50     uM  UO_0000065        None    5.0
# ...         ...   ...   ...    ...         ...         ...    ...
# 1234       None  None  IC50     uM        None        None   3.32
# 1235       None  None  IC50     uM        None        None   1.24
# 1236       None  None  IC50     uM        None        None   3.97
# 1237       None  None  IC50   None        None        None   None
# 1238       None  None  IC50     uM        None        None   50.0
#
# [1239 rows x 45 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('shp_bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#      activity_comment  activity_id  \
# 0                None       185463
# 1                None       213040
# 2                None       558682
# 3                None       576834
# 4                None       596575
# ...               ...          ...
# 1233             None     22982900
# 1234             None     22982901
# 1235             None     22982902
# 1236             None     22982903
# 1238             None     22982905
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL764641
# 1                                                    []    CHEMBL764641
# 2                                                    []    CHEMBL805163
# 3                                                    []    CHEMBL805163
# 4                                                    []    CHEMBL812686
# ...                                                 ...             ...
# 1233  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4773301
# 1234  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4773301
# 1235  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4773301
# 1236  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4773301
# 1238  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4773301
#
#                                       assay_description assay_type  \
# 0     Inhibition of Syp(N) SH2 domain block binding ...          B
# 1     Inhibition of Syp(N) SH2 domain block binding ...          B
# 2     Inhibitory activity against SH2 domain of SH-P...          F
# 3     Inhibitory activity against SH2 domain of SH-P...          F
# 4     In vitro inhibitory concentration required aga...          B
# ...                                                 ...        ...
# 1233  Inhibition of recombinant SHP2 (unknown origin...          B
# 1234  Inhibition of recombinant SHP2 (unknown origin...          B
# 1235  Inhibition of recombinant SHP2 (unknown origin...          B
# 1236  Inhibition of recombinant SHP2 (unknown origin...          B
# 1238  Inhibition of recombinant SHP2 (unknown origin...          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000357
# 1                       None                   None  BAO_0000190  BAO_0000357
# 2                       None                   None  BAO_0000190  BAO_0000019
# 3                       None                   None  BAO_0000190  BAO_0000019
# 4                       None                   None  BAO_0000190  BAO_0000357
# ...                      ...                    ...          ...          ...
# 1233                    None                   None  BAO_0000179  BAO_0000357
# 1234                    None                   None  BAO_0000179  BAO_0000357
# 1235                    None                   None  BAO_0000179  BAO_0000357
# 1236                    None                   None  BAO_0000179  BAO_0000357
# 1238                    None                   None  BAO_0000179  BAO_0000357
#
#       ... target_organism                 target_pref_name target_tax_id  \
# 0     ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# 1     ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# 2     ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# 3     ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# 4     ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# ...   ...             ...                              ...           ...
# 1233  ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# 1234  ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# 1235  ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# 1236  ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
# 1238  ...    Homo sapiens  Protein-tyrosine phosphatase 2C          9606
#
#      text_value  toid  type  units    uo_units upper_value  value
# 0          None  None  IC50     uM  UO_0000065        None  100.0
# 1          None  None  IC50     uM  UO_0000065        None  100.0
# 2          None  None  IC50     uM  UO_0000065        None   1.54
# 3          None  None  IC50     uM  UO_0000065        None   22.0
# 4          None  None  IC50     uM  UO_0000065        None    5.0
# ...         ...   ...   ...    ...         ...         ...    ...
# 1233       None  None  IC50     uM        None        None  100.0
# 1234       None  None  IC50     uM        None        None   3.32
# 1235       None  None  IC50     uM        None        None   1.24
# 1236       None  None  IC50     uM        None        None   3.97
# 1238       None  None  IC50     uM        None        None   50.0
#
# [1145 rows x 45 columns]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) > 1000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL328907  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(=O)O)NC(=O)[C@...
# 1         CHEMBL2092743  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(=O)O)NC(=O)[C@...
# 2          CHEMBL438997  CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccc(OP(=O)(O)O)...
# 3          CHEMBL263010  CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccc(OC(C(=O)O)C...
# 4          CHEMBL420456  Nc1nc(N)c2nc(CN3CCN(Cc4ccc(-c5ccccc5)cc4)CC3)n...
# ...                 ...                                                ...
# 1140      CHEMBL4778849  CC(C)(C)c1ccc(Oc2ccc(NC(=O)C3=CO[C@@H](O[C@@H]...
# 1141      CHEMBL4786441  O=C(O)C1=CO[C@@H](O[C@@H]2O[C@H](COCc3ccccc3)[...
# 1142      CHEMBL4788294  CCOS(=O)(=O)/C=C/c1ccc(OCC2=CC[C@@H]3C(C(=O)Nc...
# 1143      CHEMBL4800140  CCOS(=O)(=O)/C=C/c1ccc(OCC2=CC[C@@H]3C(C(=O)Nc...
# 1144      CHEMBL4781365  O=C1C[C@@H](O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O...
#
#      bioactivity_class standard_value
# 0             inactive       100000.0
# 1             inactive       100000.0
# 2             inactive         1540.0
# 3             inactive        22000.0
# 4             inactive         5000.0
# ...                ...            ...
# 1140          inactive       100000.0
# 1141          inactive         3320.0
# 1142          inactive         1240.0
# 1143          inactive         3970.0
# 1144          inactive        50000.0
#
# [1145 rows x 4 columns]

# %%
df3['bioactivity_class'].value_counts()
# Out:
# inactive    920
# active      225
# Name: bioactivity_class, dtype: int64

# %%
df3.to_csv('shp2_chembl.csv', index=False)
